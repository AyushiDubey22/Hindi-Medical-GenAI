# %%
import pandas as pd

# Load your CSV file
csv_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\processed\\synthetic_discharge_hindi_100.csv"
csv2_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_radiology_hindi_100.csv"

# Read CSV
df = pd.read_csv(csv_path)

# Save to Excel (.xlsx)
df.to_excel("C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_discharge_hindi_100.xlsx", index=False,engine= 'openpyxl')

print(f"✅ Excel file saved at:")
# Read CSV
df = pd.read_csv(csv2_path)

# Save to Excel (.xlsx)
df.to_excel("C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_radiology_hindi_100.xlsx", index=False,engine= 'openpyxl')
print(f"✅ Excel file saved ")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\pc\AppData\Local\Temp\ipykernel_19800\3654562502.py:4: SyntaxWarning: invalid escape sequence '\p'
#   csv_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\processed\\synthetic_discharge_hindi_100.csv"
# ✅ Excel file saved at:
# ✅ Excel file saved

# %%
import pandas as pd

# Load your CSV file
csv_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\processed\\synthetic_discharge_hindi_100.csv"
csv2_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_radiology_hindi_100.csv"

# Read CSV
df = pd.read_csv(csv_path)

# Save to Excel (.xlsx)
df.to_excel("C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_discharge_hindi_100.xlsx")

print(f"✅ Excel file saved at:")
# Read CSV
df = pd.read_csv(csv2_path)

# Save to Excel (.xlsx)
df.to_excel("C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_radiology_hindi_100.xlsx")
print(f"✅ Excel file saved ")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# <>:4: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\pc\AppData\Local\Temp\ipykernel_19800\4202471894.py:4: SyntaxWarning: invalid escape sequence '\p'
#   csv_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\processed\\synthetic_discharge_hindi_100.csv"
# C:\Users\pc\AppData\Local\Temp\ipykernel_19800\4202471894.py:4: SyntaxWarning: invalid escape sequence '\p'
#   csv_path = "C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\processed\\synthetic_discharge_hindi_100.csv"
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 11
#       8 df = pd.read_csv(csv_path)
#      10 # Save to Excel (.xlsx)
# ---> 11 df.to_excel("C:\\Users\\pc\\Desktop\\AgenticAI\\Dissertation\\Dissertation\\data\\processed\\synthetic_discharge_hindi_100.xlsx")
# ...
